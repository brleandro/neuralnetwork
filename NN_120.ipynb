# %%
from solution import *
import matplotlib.pyplot as plt

nn = NN(datapath='/Users/leandro/development/python/master/ml/hw3/cifar10.pkl',
            hidden_dims=(512, 120, 120, 120, 120, 120, 120),
            lr=0.003,
            batch_size=100,
            seed=0)

nn.train_loop(50)
# Out:
# {'train_accuracy': [0.25324489795918365,
#   0.3630408163265306,
#   0.4259183673469388,
#   0.4627551020408163,
#   0.49279591836734693,
#   0.5178163265306123,
#   0.5411020408163265,
#   0.5630204081632653,
#   0.5831428571428572,
#   0.6018367346938776,
#   0.6190816326530613,
#   0.631,
#   0.6453265306122449,
#   0.6571020408163265,
#   0.6690204081632654,
#   0.6797142857142857,
#   0.6887755102040817,
#   0.7061224489795919,
#   0.7228979591836735,
#   0.7282244897959184,
#   0.7311836734693877,
#   0.7587142857142857,
#   0.7564081632653061,
#   0.7556326530612245,
#   0.7916326530612245,
#   0.770469387755102,
#   0.7939183673469388,
#   0.8015918367346939,
#   0.8151632653061225,
#   0.7995102040816326,
#   0.8055102040816327,
#   0.8289183673469388,
#   0.7911020408163265,
#   0.8175102040816327,
#   0.8549183673469388,
#   0.8308163265306122,
#   0.8475918367346938,
#   0.8633061224489796,
#   0.843265306122449,
#   0.8632244897959184,
#   0.857265306122449,
#   0.8780204081632653,
#   0.890734693877551,
#   0.8862040816326531,
#   0.8630204081632653,
#   0.8991632653061225,
#   0.8884489795918368,
#   0.891061224489796,
#   0.8593265306122448,
#   0.9033673469387755],
#  'validation_accuracy': [0.263,
#   0.38,
#   0.442,
#   0.463,
#   0.487,
#   0.499,
#   0.514,
#   0.511,
#   0.508,
#   0.513,
#   0.517,
#   0.517,
#   0.517,
#   0.517,
#   0.512,
#   0.522,
#   0.514,
#   0.523,
#   0.522,
#   0.518,
#   0.511,
#   0.521,
#   0.524,
#   0.523,
#   0.516,
#   0.499,
#   0.512,
#   0.508,
#   0.52,
#   0.51,
#   0.494,
#   0.518,
#   0.49,
#   0.507,
#   0.502,
#   0.516,
#   0.511,
#   0.51,
#   0.502,
#   0.497,
#   0.5,
#   0.487,
#   0.495,
#   0.509,
#   0.502,
#   0.511,
#   0.502,
#   0.503,
#   0.495,
#   0.501],
#  'train_loss': [2.034784575989558,
#   1.7589464614919852,
#   1.6024523551071286,
#   1.502915773922226,
#   1.4230866358541372,
#   1.355113938515601,
#   1.293671582204553,
#   1.2350776764741749,
#   1.1826833057335582,
#   1.1322079214322676,
#   1.0852051376866543,
#   1.0514069476598664,
#   1.0141778644565356,
#   0.9796562627352364,
#   0.9478531368428186,
#   0.9169377486555447,
#   0.8966718023136904,
#   0.8481592949317847,
#   0.8011675724518308,
#   0.7838244846041436,
#   0.7851950754857576,
#   0.6996463794687356,
#   0.7056405073160846,
#   0.714092975146499,
#   0.6045087393033559,
#   0.6850073537741825,
#   0.6005434738782891,
#   0.5791436989899355,
#   0.5313173891326339,
#   0.5978042501472903,
#   0.5889512120122885,
#   0.508925720432145,
#   0.6421104244008734,
#   0.5469499678715537,
#   0.432542629210718,
#   0.5157145778247081,
#   0.45419720702812527,
#   0.3995513721200822,
#   0.49966461805611584,
#   0.40869411776564835,
#   0.43463702431283086,
#   0.3663322950004797,
#   0.32512616342491824,
#   0.3439970428790747,
#   0.4280571075482549,
#   0.30426850013590334,
#   0.34128024190272105,
#   0.329238849066928,
#   0.4653866256237681,
#   0.2888274032524943],
#  'validation_loss': [2.038672206294976,
#   1.7694271712792298,
#   1.6020674174986296,
#   1.519218975638435,
#   1.469760256444343,
#   1.4401057074039108,
#   1.4231190349077647,
#   1.4129001363649725,
#   1.4106186595372778,
#   1.4117801147587778,
#   1.4182008880128893,
#   1.436400267117364,
#   1.45721807791924,
#   1.4728897857286547,
#   1.5131188454480784,
#   1.5455524683650392,
#   1.5721717253656367,
#   1.6105215026136483,
#   1.6253472804971794,
#   1.686629400116674,
#   1.7408781707516219,
#   1.7047312386326325,
#   1.7913560225733554,
#   1.8245809803108892,
#   1.9004286022862382,
#   2.0659442233366865,
#   2.0287065896792726,
#   2.0963362659816633,
#   2.060326728191769,
#   2.194169194492301,
#   2.301661175506123,
#   2.264168087388998,
#   2.3473366481254296,
#   2.427874595141795,
#   2.483558801485346,
#   2.385531818693743,
#   2.5006019790642267,
#   2.4936165345433547,
#   2.7060127620951144,
#   2.6945520622000037,
#   2.5844887463328408,
#   2.710460964792028,
#   2.7408381422467416,
#   2.760707635674942,
#   2.814578698304425,
#   2.8827090178701686,
#   2.925817677198478,
#   2.9989912282297957,
#   3.261907688409191,
#   3.047661464535303]}

# %%
plt.interactive(True)
plt.plot(list(range(50)), nn.train_logs['train_accuracy'], '-',label='Training accuracy')
plt.plot(list(range(50)), nn.train_logs['validation_accuracy'], '-',label='Validation accuracy')
plt.legend()
plt.title(f"Accuracy evolution for 7 hidden layers NN ")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %%
plt.plot(list(range(50)), nn.train_logs['train_loss'], '-',label='Training loss')
plt.plot(list(range(50)), nn.train_logs['validation_loss'], '-',label='Validation loss')
plt.legend()
plt.title(f"Loss evolution for 7 hidden layers NN ")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
